# %% [markdown]
# # pandas 库
# - [官方网站](http://pandas.pydata.org/)
#
# pandas中的datafram的操作，很大一部分跟numpy中的二维数组的操作是近似的

# %%
import pandas as pd

# %% [markdown]
# ## Introducing the Pandas DataFrame
# Pandas DataFrames are data structures that contain:
#
# -   Data organized in two dimensions, rows and columns
# -   Labels that correspond to the rows and columns

# %%
data = {
     'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
     'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai',
              'Manchester', 'Cairo', 'Osaka'],
     'age': [41, 28, 33, 34, 38, 31, 37],
     'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
 }

row_labels = [101, 102, 103, 104, 105, 106, 107]
df = pd.DataFrame(data=data, index=row_labels)
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %% [markdown]
# ## 读取文件 快速预览

# %%
df = pd.read_csv('text_files/death_valley_2014.csv')
df.head() # 读取文件,默认显示前5行
# Out:
#         PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1              63.0               42.0              24.0
# 1  2014-1-2              66.0               47.0              28.0
# 2  2014-1-3              64.0               46.0              28.0
# 3  2014-1-4              66.0               47.0              28.0
# 4  2014-1-5              61.0               44.0              26.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            14.0             9.0            5.0          48.0
# 1            22.0            19.0           16.0          58.0
# 2            24.0            21.0           15.0          61.0
# 3            25.0            21.0           16.0          61.0
# 4            18.0             7.0           -1.0          56.0
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0            32.0           15.0       ...                          NaN
# 1            36.0           19.0       ...                         10.0
# 2            40.0           22.0       ...                          NaN
# 3            42.0           20.0       ...                          NaN
# 4            30.0            9.0       ...                          NaN
#
#     Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 0                    NaN                   NaN                 7.0
# 1                   10.0                  10.0                 9.0
# 2                    NaN                   NaN                 9.0
# 3                    NaN                   NaN                 9.0
# 4                    NaN                   NaN                10.0
#
#     Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 0                  2.0                 NaN              0.0          0.0
# 1                  2.0                 NaN              0.0          0.0
# 2                  3.0                 NaN              0.0          0.0
# 3                  4.0                 NaN              0.0          0.0
# 4                  4.0                 NaN              0.0          0.0
#
#     Events   WindDirDegrees
# 0      NaN              203
# 1      NaN              135
# 2      NaN              205
# 3      NaN              148
# 4      NaN              195
#
# [5 rows x 23 columns]

# %%
df.tail() # 显示最后几行
# Out:
#             PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 355  2014-12-25              53.0               47.0              41.0
# 356  2014-12-26              51.0               42.0              34.0
# 357  2014-12-27              46.0               37.0              27.0
# 358  2014-12-28              50.0               38.0              25.0
# 359  2014-12-29              48.0               33.0              21.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 355            29.0            15.0            9.0          46.0
# 356            16.0            13.0           10.0          44.0
# 357            18.0            15.0           11.0          66.0
# 358            21.0            18.0           14.0          75.0
# 359            22.0            19.0           17.0          82.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 355            29.0           17.0       ...                         10.0
# 356            31.0           19.0       ...                         10.0
# 357            44.0           23.0       ...                         10.0
# 358            54.0           24.0       ...                         10.0
# 359            64.0           28.0       ...                         10.0
#
#       Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 355                   10.0                  10.0                32.0
# 356                   10.0                  10.0                13.0
# 357                   10.0                  10.0                 9.0
# 358                   10.0                  10.0                 8.0
# 359                   10.0                  10.0                 7.0
#
#       Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 355                 18.0                39.0              0.0          0.0
# 356                  8.0                 NaN              0.0          0.0
# 357                  3.0                 NaN              0.0          0.0
# 358                  4.0                 NaN              0.0          0.0
# 359                  3.0                 NaN              0.0          0.0
#
#       Events   WindDirDegrees
# 355      NaN              319
# 356      NaN              332
# 357      NaN              186
# 358      NaN              221
# 359      NaN              249
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 23 columns):
# PST                           360 non-null object
# Max TemperatureF              359 non-null float64
# Mean TemperatureF             359 non-null float64
# Min TemperatureF              359 non-null float64
# Max Dew PointF                359 non-null float64
# MeanDew PointF                359 non-null float64
# Min DewpointF                 359 non-null float64
# Max Humidity                  359 non-null float64
#  Mean Humidity                359 non-null float64
#  Min Humidity                 359 non-null float64
#  Max Sea Level PressureIn     359 non-null float64
#  Mean Sea Level PressureIn    359 non-null float64
#  Min Sea Level PressureIn     359 non-null float64
#  Max VisibilityMiles          355 non-null float64
#  Mean VisibilityMiles         355 non-null float64
#  Min VisibilityMiles          355 non-null float64
#  Max Wind SpeedMPH            359 non-null float64
#  Mean Wind SpeedMPH           359 non-null float64
#  Max Gust SpeedMPH            211 non-null float64
# PrecipitationIn               360 non-null float64
#  CloudCover                   343 non-null float64
#  Events                       18 non-null object
#  WindDirDegrees               360 non-null int64
# dtypes: float64(20), int64(1), object(2)
# memory usage: 64.8+ KB

# %%
# 把所有有数据类型的数据做一个简单统计
df.describe()
# Out:
#        Max TemperatureF  Mean TemperatureF  Min TemperatureF  Max Dew PointF  \
# count        359.000000         359.000000        359.000000      359.000000
# mean          82.749304          67.016713         51.791086       35.342618
# std           16.520466          15.016741         14.953497       12.104394
# min           37.000000          33.000000         21.000000       -6.000000
# 25%           70.000000          54.000000         39.000000       27.500000
# 50%           82.000000          66.000000         51.000000       36.000000
# 75%           98.000000          81.500000         64.000000       44.000000
# max          111.000000          94.000000         84.000000       66.000000
#
#        MeanDew PointF  Min DewpointF  Max Humidity   Mean Humidity  \
# count      359.000000     359.000000    359.000000      359.000000
# mean        28.905292      21.448468     46.454039       29.671309
# std         12.004047      12.232021     20.884425       17.599931
# min         -9.000000     -18.000000     15.000000        9.000000
# 25%         20.000000      13.000000     31.000000       18.000000
# 50%         30.000000      22.000000     42.000000       25.000000
# 75%         38.000000      31.000000     56.000000       34.000000
# max         60.000000      48.000000    100.000000       95.000000
#
#         Min Humidity   Max Sea Level PressureIn       ...         \
# count      359.00000                 359.000000       ...
# mean        15.51532                  30.013593       ...
# std         13.22661                   0.179104       ...
# min          4.00000                  29.670000       ...
# 25%          8.00000                  29.880000       ...
# 50%         12.00000                  29.980000       ...
# 75%         17.00000                  30.130000       ...
# max         93.00000                  30.540000       ...
#
#         Min Sea Level PressureIn   Max VisibilityMiles   Mean VisibilityMiles  \
# count                 359.000000                 355.0             355.000000
# mean                   29.853621                  10.0               9.915493
# std                     0.172925                   0.0               0.473790
# min                    29.510000                  10.0               6.000000
# 25%                    29.720000                  10.0              10.000000
# 50%                    29.820000                  10.0              10.000000
# 75%                    29.970000                  10.0              10.000000
# max                    30.380000                  10.0              10.000000
#
#         Min VisibilityMiles   Max Wind SpeedMPH   Mean Wind SpeedMPH  \
# count            355.000000          359.000000           359.000000
# mean               9.521127           16.788301             7.272981
# std                1.687936            7.207211             3.812376
# min                0.000000            6.000000             2.000000
# 25%               10.000000           10.000000             5.000000
# 50%               10.000000           15.000000             6.000000
# 75%               10.000000           22.000000             9.000000
# max               10.000000           38.000000            25.000000
#
#         Max Gust SpeedMPH  PrecipitationIn   CloudCover   WindDirDegrees
# count          211.000000       360.000000   343.000000       360.000000
# mean            29.293839         0.006583     1.309038       201.569444
# std              7.992193         0.074207     1.791176        40.094605
# min             16.000000         0.000000     0.000000        -1.000000
# 25%             23.000000         0.000000     0.000000       183.000000
# 50%             28.000000         0.000000     0.000000       196.500000
# 75%             36.000000         0.000000     2.000000       220.000000
# max             51.000000         1.160000     8.000000       346.000000
#
# [8 rows x 21 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 信息提取

# %% [markdown]
# ### 获取列名

# %%
df.columns
# Out:
# Index(['PST', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# ### 获取索引

# %%
df.index
# Out:
# RangeIndex(start=0, stop=360, step=1)

# %% [markdown]
# 说明从0开始,360行结束(不包括360)

# %% [markdown]
# ### 获取某一行信息

# %%
df.loc[0]  # 如果索引不是数字,那么里面填对应索引
df.iloc[0] #  如果索引不是数字,那么里面还是填数字
# df.ix[0]   # 这个是自动指定
'''
.ix is deprecated. Please use
.loc for label based indexing or
.iloc for positional indexing
第三个好像有警告
'''
# Out:
# '\n.ix is deprecated. Please use\n.loc for label based indexing or\n.iloc for positional indexing\n第三个好像有警告\n'

# %%
df.loc[360]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [360] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-12a4e65cf339> in <module>
# ----> 1 df.loc[360]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [360] is not in the [index]'

# %% [markdown]
# ### 获取某一列信息

# %%
# 名字不带空格可以这样访问
df.PST[:10]
# Out:
# 0     2014-1-1
# 1     2014-1-2
# 2     2014-1-3
# 3     2014-1-4
# 4     2014-1-5
# 5     2014-1-6
# 6     2014-1-7
# 7     2014-1-8
# 8     2014-1-9
# 9    2014-1-10
# Name: PST, dtype: object

# %%
# 名字带空格这样访问
df['Max TemperatureF'][:3]
# Out:
# 0    63.0
# 1    66.0
# 2    64.0
# Name: Max TemperatureF, dtype: float64

# %%
# 访问多列
df[['Max TemperatureF','Min TemperatureF']][:3]
# Out:
#    Max TemperatureF  Min TemperatureF
# 0              63.0              24.0
# 1              66.0              28.0
# 2              64.0              28.0

# %% [markdown]
# ## 数据处理

# %% [markdown]
# ### 统计空数据数量

# %%
df.isnull().sum()
# Out:
# PST                             0
# Max TemperatureF                1
# Mean TemperatureF               1
# Min TemperatureF                1
# Max Dew PointF                  1
# MeanDew PointF                  1
# Min DewpointF                   1
# Max Humidity                    1
#  Mean Humidity                  1
#  Min Humidity                   1
#  Max Sea Level PressureIn       1
#  Mean Sea Level PressureIn      1
#  Min Sea Level PressureIn       1
#  Max VisibilityMiles            5
#  Mean VisibilityMiles           5
#  Min VisibilityMiles            5
#  Max Wind SpeedMPH              1
#  Mean Wind SpeedMPH             1
#  Max Gust SpeedMPH            149
# PrecipitationIn                 0
#  CloudCover                    17
#  Events                       342
#  WindDirDegrees                 0
# dtype: int64

# %%
# 将空赋值
df.fillna(0)
# Out:
#             PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      2014-1-1              63.0               42.0              24.0
# 1      2014-1-2              66.0               47.0              28.0
# 2      2014-1-3              64.0               46.0              28.0
# 3      2014-1-4              66.0               47.0              28.0
# 4      2014-1-5              61.0               44.0              26.0
# 5      2014-1-6              57.0               40.0              23.0
# 6      2014-1-7              57.0               44.0              30.0
# 7      2014-1-8              60.0               40.0              21.0
# 8      2014-1-9              57.0               42.0              27.0
# 9     2014-1-10              63.0               44.0              26.0
# 10    2014-1-11              64.0               47.0              30.0
# 11    2014-1-12              63.0               50.0              35.0
# 12    2014-1-13              64.0               46.0              28.0
# 13    2014-1-14              70.0               50.0              30.0
# 14    2014-1-15              70.0               50.0              30.0
# 15    2014-1-16              72.0               50.0              27.0
# 16    2014-1-17              71.0               50.0              28.0
# 17    2014-1-18              69.0               48.0              28.0
# 18    2014-1-19              69.0               48.0              27.0
# 19    2014-1-20              68.0               49.0              30.0
# 20    2014-1-21              62.0               45.0              28.0
# 21    2014-1-22              70.0               52.0              34.0
# 22    2014-1-23              66.0               46.0              27.0
# 23    2014-1-24              66.0               54.0              41.0
# 24    2014-1-25              68.0               54.0              39.0
# 25    2014-1-26              63.0               48.0              33.0
# 26    2014-1-27              71.0               50.0              28.0
# 27    2014-1-28              71.0               52.0              34.0
# 28    2014-1-29              72.0               54.0              35.0
# 29    2014-1-30              66.0               60.0              52.0
# ..          ...               ...                ...               ...
# 330  2014-11-29              77.0               60.0              44.0
# 331  2014-11-30              66.0               59.0              52.0
# 332   2014-12-1              61.0               50.0              39.0
# 333   2014-12-2              50.0               47.0              44.0
# 334   2014-12-3              60.0               55.0              50.0
# 335   2014-12-4              63.0               56.0              48.0
# 336   2014-12-5              60.0               53.0              46.0
# 337   2014-12-6              63.0               52.0              42.0
# 338   2014-12-7              63.0               51.0              39.0
# 339   2014-12-8              66.0               52.0              39.0
# 340   2014-12-9              66.0               52.0              37.0
# 341  2014-12-10              60.0               48.0              37.0
# 342  2014-12-11              62.0               52.0              41.0
# 343  2014-12-12              54.0               50.0              46.0
# 344  2014-12-13              57.0               47.0              37.0
# 345  2014-12-14              54.0               43.0              32.0
# 346  2014-12-15              51.0               42.0              32.0
# 347  2014-12-16              48.0               41.0              34.0
# 348  2014-12-17              53.0               47.0              37.0
# 349  2014-12-18              54.0               44.0              33.0
# 350  2014-12-19              52.0               42.0              33.0
# 351  2014-12-20              37.0               37.0              36.0
# 352  2014-12-22              61.0               50.0              39.0
# 353  2014-12-23              68.0               52.0              35.0
# 354  2014-12-24              60.0               48.0              36.0
# 355  2014-12-25              53.0               47.0              41.0
# 356  2014-12-26              51.0               42.0              34.0
# 357  2014-12-27              46.0               37.0              27.0
# 358  2014-12-28              50.0               38.0              25.0
# 359  2014-12-29              48.0               33.0              21.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              14.0             9.0            5.0          48.0
# 1              22.0            19.0           16.0          58.0
# 2              24.0            21.0           15.0          61.0
# 3              25.0            21.0           16.0          61.0
# 4              18.0             7.0           -1.0          56.0
# 5               7.0             3.0           -1.0          37.0
# 6              10.0             7.0            5.0          37.0
# 7              11.0             8.0            3.0          46.0
# 8              19.0            14.0            8.0          52.0
# 9              25.0            20.0           14.0          66.0
# 10             29.0            25.0           17.0          67.0
# 11             29.0            22.0           17.0          49.0
# 12             16.0            14.0           11.0          51.0
# 13             15.0            10.0            7.0          47.0
# 14             12.0             8.0            4.0          34.0
# 15             10.0             3.0           -1.0          39.0
# 16              7.0             3.0            1.0          31.0
# 17              9.0             4.0           -1.0          31.0
# 18              8.0             5.0            1.0          33.0
# 19             10.0             6.0            3.0          35.0
# 20             11.0             8.0            4.0          36.0
# 21             11.0             9.0            4.0          36.0
# 22             17.0            10.0            3.0          36.0
# 23             19.0            16.0           15.0          36.0
# 24             17.0            15.0           11.0          36.0
# 25             19.0            14.0           11.0          42.0
# 26             19.0            15.0           12.0          49.0
# 27             20.0            17.0           14.0          44.0
# 28             34.0            22.0           15.0          50.0
# 29             42.0            36.0           24.0          59.0
# ..              ...             ...            ...           ...
# 330            21.0            12.0            5.0          23.0
# 331            46.0            35.0           10.0          62.0
# 332            44.0            39.0           34.0          83.0
# 333            50.0            46.0           33.0         100.0
# 334            53.0            51.0           48.0         100.0
# 335            53.0            49.0           46.0          93.0
# 336            52.0            49.0           45.0          93.0
# 337            51.0            46.0           41.0         100.0
# 338            46.0            42.0           39.0          97.0
# 339            44.0            41.0           38.0          93.0
# 340            42.0            39.0           35.0          97.0
# 341            43.0            39.0           35.0          93.0
# 342            44.0            41.0           38.0          93.0
# 343            50.0            43.0           36.0         100.0
# 344            40.0            36.0           34.0          86.0
# 345            38.0            35.0           30.0          92.0
# 346            39.0            35.0           30.0          96.0
# 347            41.0            38.0           33.0          97.0
# 348            43.0            41.0           35.0          97.0
# 349            39.0            36.0           32.0          96.0
# 350            41.0            37.0           32.0          96.0
# 351            35.0            35.0           35.0          97.0
# 352            44.0            42.0           38.0          97.0
# 353            43.0            38.0           34.0          96.0
# 354            41.0            37.0           33.0          93.0
# 355            29.0            15.0            9.0          46.0
# 356            16.0            13.0           10.0          44.0
# 357            18.0            15.0           11.0          66.0
# 358            21.0            18.0           14.0          75.0
# 359            22.0            19.0           17.0          82.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0              32.0           15.0       ...                          0.0
# 1              36.0           19.0       ...                         10.0
# 2              40.0           22.0       ...                          0.0
# 3              42.0           20.0       ...                          0.0
# 4              30.0            9.0       ...                          0.0
# 5              24.0           11.0       ...                         10.0
# 6              26.0           14.0       ...                         10.0
# 7              29.0           14.0       ...                         10.0
# 8              36.0           20.0       ...                         10.0
# 9              42.0           21.0       ...                         10.0
# 10             38.0           22.0       ...                         10.0
# 11             33.0           18.0       ...                         10.0
# 12             31.0           14.0       ...                         10.0
# 13             25.0            9.0       ...                         10.0
# 14             21.0            9.0
# <b>limit_output extension: Maximum message size of 10000 exceeded with 28687 characters</b>

# %%
# 直接填充
df.fillna(0,inplace=True)
df.isnull().sum()
# Out:
# PST                           0
# Max TemperatureF              0
# Mean TemperatureF             0
# Min TemperatureF              0
# Max Dew PointF                0
# MeanDew PointF                0
# Min DewpointF                 0
# Max Humidity                  0
#  Mean Humidity                0
#  Min Humidity                 0
#  Max Sea Level PressureIn     0
#  Mean Sea Level PressureIn    0
#  Min Sea Level PressureIn     0
#  Max VisibilityMiles          0
#  Mean VisibilityMiles         0
#  Min VisibilityMiles          0
#  Max Wind SpeedMPH            0
#  Mean Wind SpeedMPH           0
#  Max Gust SpeedMPH            0
# PrecipitationIn               0
#  CloudCover                   0
#  Events                       0
#  WindDirDegrees               0
# dtype: int64

# %% [markdown]
# ### 求中位数

# %%
df.median()
# Out:
# Max TemperatureF               82.00
# Mean TemperatureF              66.00
# Min TemperatureF               51.00
# Max Dew PointF                 36.00
# MeanDew PointF                 30.00
# Min DewpointF                  22.00
# Max Humidity                   42.00
#  Mean Humidity                 25.00
#  Min Humidity                  12.00
#  Max Sea Level PressureIn      29.98
#  Mean Sea Level PressureIn     29.89
#  Min Sea Level PressureIn      29.82
#  Max VisibilityMiles           10.00
#  Mean VisibilityMiles          10.00
#  Min VisibilityMiles           10.00
#  Max Wind SpeedMPH             15.00
#  Mean Wind SpeedMPH             6.00
#  Max Gust SpeedMPH             28.00
# PrecipitationIn                 0.00
#  CloudCover                     0.00
#  WindDirDegrees               196.50
# dtype: float64

# %% [markdown]
# ### 筛选

# %%
df['Max TemperatureF'] > 105
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 330    False
# 331    False
# 332    False
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# 338    False
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# 344    False
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# 350    False
# 351    False
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# 357    False
# 358    False
# 359    False
# Name: Max TemperatureF, Length: 360, dtype: bool

# %%
type(df['Max TemperatureF'] > 65)
# Out:
# pandas.core.series.Series

# %%
df[df['Max TemperatureF'] > 109]
# Out:
#            PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 191  2014-7-13             111.0               91.0              71.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 191            48.0            39.0           31.0          33.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 191            17.0            8.0       ...                         10.0
#
#       Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 191                   10.0                  10.0                13.0
#
#       Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 191                  5.0                 NaN              0.0          0.0
#
#       Events   WindDirDegrees
# 191      NaN              195
#
# [1 rows x 23 columns]

# %% [markdown]
# ### 多条件的筛选

# %%
df[(df['Max TemperatureF'] > 105) & (df['Min TemperatureF']>70)]
# Out:
#            PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 156   2014-6-8             106.0               88.0              71.0
# 157   2014-6-9             108.0               90.0              72.0
# 179   2014-7-1             109.0               94.0              78.0
# 180   2014-7-2             109.0               91.0              73.0
# 181   2014-7-3             108.0               90.0              73.0
# 185   2014-7-7             106.0               92.0              80.0
# 186   2014-7-8             107.0               92.0              77.0
# 187   2014-7-9             106.0               90.0              73.0
# 191  2014-7-13             111.0               91.0              71.0
# 201  2014-7-23             108.0               90.0              72.0
# 203  2014-7-25             109.0               92.0              75.0
# 204  2014-7-26             106.0               89.0              73.0
# 205  2014-7-27             107.0               94.0              81.0
# 208  2014-7-30             106.0               90.0              75.0
# 209  2014-7-31             106.0               91.0              77.0
# 210   2014-8-1             108.0               91.0              75.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 156            37.0            28.0           15.0          24.0
# 157            39.0            29.0           16.0          29.0
# 179            43.0            37.0           22.0          28.0
# 180            42.0            35.0           17.0          28.0
# 181            41.0            34.0           24.0          25.0
# 185            52.0            44.0           33.0          38.0
# 186            48.0            39.0           31.0          28.0
# 187            43.0            37.0           32.0          27.0
# 191            48.0            39.0           31.0          33.0
# 201            48.0            37.0           16.0          37.0
# 203            42.0            32.0           19.0          23.0
# 204            44.0            38.0           26.0          28.0
# 205            46.0            41.0           36.0          22.0
# 208            54.0            49.0           43.0          33.0
# 209            53.0            48.0           44.0          42.0
# 210            47.0            43.0           38.0          34.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 156            13.0            4.0       ...                         10.0
# 157            13.0            4.0       ...                         10.0
# 179            16.0            5.0       ...                         10.0
# 180            15.0            4.0       ...                         10.0
# 181            15.0            6.0       ...                         10.0
# 185            20.0           10.0       ...                         10.0
# 186            16.0            8.0       ...                         10.0
# 187            15.0            9.0       ...                         10.0
# 191            17.0            8.0       ...                         10.0
# 201            20.0            4.0       ...                         10.0
# 203            14.0            5.0       ...                         10.0
# 204            17.0            6.0       ...                         10.0
# 205            16.0           12.0       ...                         10.0
# 208            24.0           13.0       ...                         10.0
# 209            24.0           13.0       ...                         10.0
# 210            19.0            9.0       ...                         10.0
#
#       Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 156                   10.0                  10.0                10.0
# 157                   10.0                  10.0                20.0
# 179                   10.0                  10.0                22.0
# 180                   10.0                  10.0                22.0
# 181                   10.0                  10.0                28.0
# 185                   10.0                  10.0                20.0
# 186                   10.0                  10.0                13.0
# 187                   10.0                  10.0                17.0
# 191                   10.0                  10.0                13.0
# 201                   10.0                  10.0                20.0
# 203                   10.0                  10.0                22.0
# 204                   10.0                  10.0                15.0
# 205                   10.0                  10.0                23.0
# 208                    7.0                   1.0                36.0
# 209                   10.0                  10.0                14.0
# 210                   10.0                  10.0                16.0
#
#       Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 156                  5.0                18.0              0.0          2.0
# 157                  9.0                28.0              0.0          0.0
# 179                  9.0                30.0              0.0          0.0
# 180                 10.0                29.0              0.0          0.0
# 181                 10.0                34.0              0.0          0.0
# 185                  6.0                23.0              0.0          2.0
# 186                  6.0                22.0              0.0          1.0
# 187                  8.0                26.0              0.0          1.0
# 191                  5.0                 NaN              0.0          0.0
# 201                 10.0                28.0              0.0          0.0
# 203                 10.0                32.0              0.0          2.0
# 204                  9.0                21.0              0.0          0.0
# 205                  8.0                33.0              0.0          0.0
# 208                 14.0                48.0              0.0          3.0
# 209                  7.0                24.0              0.0          1.0
# 210                  7.0                22.0              0.0          0.0
#
#       Events   WindDirDegrees
# 156      NaN              192
# 157      NaN              200
# 179      NaN              189
# 180      NaN              187
# 181      NaN              200
# 185      NaN              218
# 186      NaN              183
# 187      NaN              179
# 191      NaN              195
# 201      NaN              193
# 203      NaN              191
# 204      NaN              189
# 205      NaN              170
# 208      NaN              308
# 209      NaN              264
# 210      NaN              191
#
# [16 rows x 23 columns]

# %%
df[(df['Max TemperatureF'] > 105) and (df['Min TemperatureF']>70)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-3fb5c54a58c2> in <module>
# ----> 1 df[(df['Max TemperatureF'] > 105) and (df['Min TemperatureF']>70)]
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### 排序

# %%
df.sort_values(['Mean TemperatureF'])[:5]
# Out:
#             PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 359  2014-12-29              48.0               33.0              21.0
# 357  2014-12-27              46.0               37.0              27.0
# 351  2014-12-20              37.0               37.0              36.0
# 358  2014-12-28              50.0               38.0              25.0
# 34     2014-2-4              54.0               39.0              24.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 359            22.0            19.0           17.0          82.0
# 357            18.0            15.0           11.0          66.0
# 351            35.0            35.0           35.0          97.0
# 358            21.0            18.0           14.0          75.0
# 34             27.0            22.0           18.0          78.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 359            64.0           28.0       ...                         10.0
# 357            44.0           23.0       ...                         10.0
# 351            95.0           93.0       ...                         10.0
# 358            54.0           24.0       ...                         10.0
# 34             52.0           31.0       ...                         10.0
#
#       Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 359                   10.0                  10.0                 7.0
# 357                   10.0                  10.0                 9.0
# 351                   10.0                   9.0                 6.0
# 358                   10.0                  10.0                 8.0
# 34                    10.0                  10.0                 9.0
#
#       Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 359                  3.0                 NaN              0.0          0.0
# 357                  3.0                 NaN              0.0          0.0
# 351                  2.0                 NaN              0.0          0.0
# 358                  4.0                 NaN              0.0          0.0
# 34                   4.0                 NaN              0.0          3.0
#
#       Events   WindDirDegrees
# 359      NaN              249
# 357      NaN              186
# 351      NaN              220
# 358      NaN              221
# 34       NaN              149
#
# [5 rows x 23 columns]

# %%
df.sort_values(['Mean TemperatureF'])[:-3:-1] # 倒着排序只能用切片了
# Out:
#            PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 46   2014-2-16               NaN                NaN               NaN
# 205  2014-7-27             107.0               94.0              81.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 46              NaN             NaN            NaN           NaN
# 205            46.0            41.0           36.0          22.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 46              NaN            NaN       ...                          NaN
# 205            16.0           12.0       ...                         10.0
#
#       Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 46                     NaN                   NaN                 NaN
# 205                   10.0                  10.0                23.0
#
#       Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 46                   NaN                 NaN              0.0          NaN
# 205                  8.0                33.0              0.0          0.0
#
#       Events   WindDirDegrees
# 46       NaN               -1
# 205      NaN              170
#
# [2 rows x 23 columns]

# %%
#　多个数据排序
df.sort_values(['Mean TemperatureF','Min TemperatureF'])[:5]
# Out:
#             PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 359  2014-12-29              48.0               33.0              21.0
# 357  2014-12-27              46.0               37.0              27.0
# 351  2014-12-20              37.0               37.0              36.0
# 358  2014-12-28              50.0               38.0              25.0
# 34     2014-2-4              54.0               39.0              24.0
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 359            22.0            19.0           17.0          82.0
# 357            18.0            15.0           11.0          66.0
# 351            35.0            35.0           35.0          97.0
# 358            21.0            18.0           14.0          75.0
# 34             27.0            22.0           18.0          78.0
#
#       Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 359            64.0           28.0       ...                         10.0
# 357            44.0           23.0       ...                         10.0
# 351            95.0           93.0       ...                         10.0
# 358            54.0           24.0       ...                         10.0
# 34             52.0           31.0       ...                         10.0
#
#       Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 359                   10.0                  10.0                 7.0
# 357                   10.0                  10.0                 9.0
# 351                   10.0                   9.0                 6.0
# 358                   10.0                  10.0                 8.0
# 34                    10.0                  10.0                 9.0
#
#       Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 359                  3.0                 NaN              0.0          0.0
# 357                  3.0                 NaN              0.0          0.0
# 351                  2.0                 NaN              0.0          0.0
# 358                  4.0                 NaN              0.0          0.0
# 34                   4.0                 NaN              0.0          3.0
#
#       Events   WindDirDegrees
# 359      NaN              249
# 357      NaN              186
# 351      NaN              220
# 358      NaN              221
# 34       NaN              149
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 获取数组

# %%
df['Mean TemperatureF'].values
# Out:
# array([42., 47., 46., 47., 44., 40., 44., 40., 42., 44., 47., 50., 46.,
#        50., 50., 50., 50., 48., 48., 49., 45., 52., 46., 54., 54., 48.,
#        50., 52., 54., 60., 52., 44., 40., 40., 39., 41., 45., 50., 56.,
#        57., 62., 54., 54., 56., 58., 60., nan, 56., 61., 52., 53., 54.,
#        55., 56., 56., 55., 62., 52., 50., 48., 51., 59., 58., 64., 62.,
#        58., 60., 62., 58., 58., 56., 58., 62., 62., 68., 57., 54., 56.,
#        61., 62., 62., 62., 62., 58., 58., 55., 64., 60., 58., 54., 51.,
#        50., 58., 54., 63., 65., 67., 74., 70., 72., 68., 70., 66., 69.,
#        70., 70., 71., 70., 72., 72., 65., 60., 65., 64., 58., 58., 63.,
#        70., 69., 70., 75., 75., 80., 72., 60., 59., 66., 64., 69., 68.,
#        70., 70., 75., 80., 84., 80., 74., 64., 61., 64., 68., 77., 79.,
#        83., 82., 84., 75., 76., 80., 75., 80., 76., 78., 81., 81., 82.,
#        88., 90., 88., 86., 84., 86., 78., 78., 81., 78., 74., 78., 82.,
#        84., 83., 83., 84., 86., 85., 81., 86., 86., 88., 94., 91., 90.,
#        90., 88., 88., 92., 92., 90., 86., 84., 86., 91., 93., 90., 90.,
#        88., 86., 87., 85., 86., 86., 90., 88., 92., 89., 94., 88., 88.,
#        90., 91., 91., 87., 76., 80., 82., 82., 82., 83., 86., 84., 85.,
#        86., 87., 85., 83., 84., 84., 88., 82., 78., 77., 82., 84., 81.,
#        80., 80., 80., 83., 84., 85., 88., 82., 85., 85., 82., 81., 82.,
#        86., 84., 80., 79., 80., 82., 82., 84., 87., 87., 86., 84., 75.,
#        77., 78., 77., 78., 76., 82., 76., 68., 64., 68., 70., 70., 68.,
#        68., 71., 73., 73., 74., 72., 74., 70., 70., 72., 66., 67., 74.,
#        64., 66., 65., 70., 70., 66., 64., 67., 68., 74., 64., 60., 62.,
#        62., 64., 62., 54., 52., 53., 50., 57., 60., 61., 62., 62., 62.,
#        56., 56., 59., 60., 54., 49., 44., 46., 52., 52., 55., 50., 52.,
#        47., 48., 51., 53., 52., 60., 59., 50., 47., 55., 56., 53., 52.,
#        51., 52., 52., 48., 52., 50., 47., 43., 42., 41., 47., 44., 42.,
#        37., 50., 52., 48., 47., 42., 37., 38., 33.])

# %% [markdown]
# ### 简单统计

# %%
df['Mean TemperatureF'].value_counts()
# Out:
# 62.0    16
# 70.0    15
# 52.0    15
# 50.0    14
# 84.0    14
# 86.0    14
# 82.0    14
# 58.0    12
# 80.0    11
# 54.0    11
# 64.0    11
# 88.0    11
# 60.0    10
# 56.0    10
# 68.0     9
# 78.0     8
# 90.0     8
# 47.0     8
# 85.0     7
# 48.0     7
# 74.0     7
# 81.0     6
# 72.0     6
# 83.0     6
# 44.0     6
# 75.0     6
# 55.0     5
# 42.0     5
# 66.0     5
# 76.0     5
# 87.0     5
# 46.0     4
# 40.0     4
# 65.0     4
# 77.0     4
# 59.0     4
# 51.0     4
# 91.0     4
# 53.0     4
# 61.0     4
# 92.0     3
# 57.0     3
# 69.0     3
# 67.0     3
# 94.0     2
# 63.0     2
# 37.0     2
# 73.0     2
# 49.0     2
# 45.0     2
# 71.0     2
# 41.0     2
# 79.0     2
# 38.0     1
# 93.0     1
# 89.0     1
# 39.0     1
# 43.0     1
# 33.0     1
# Name: Mean TemperatureF, dtype: int64

# %% [markdown]
# ### 分类

# %%
def is_cool(temperature):
    if temperature < 50:
        # 大约是10摄氏度
        return 'cool'
    else:
        return 'not_so_cool'

# 利用map函数
df['is_cool?'] = df['Mean TemperatureF'].map(is_cool)
df[['is_cool?','Mean TemperatureF']].head(15)
# Out:
#        is_cool?  Mean TemperatureF
# 0          cool               42.0
# 1          cool               47.0
# 2          cool               46.0
# 3          cool               47.0
# 4          cool               44.0
# 5          cool               40.0
# 6          cool               44.0
# 7          cool               40.0
# 8          cool               42.0
# 9          cool               44.0
# 10         cool               47.0
# 11  not_so_cool               50.0
# 12         cool               46.0
# 13  not_so_cool               50.0
# 14  not_so_cool               50.0

# %% [markdown]
# ### 对全体应用函数

# %%
df.applymap(lambda x: str(x)+'...').head()
# Out:
#            PST Max TemperatureF Mean TemperatureF Min TemperatureF  \
# 0  2014-1-1...          63.0...           42.0...          24.0...
# 1  2014-1-2...          66.0...           47.0...          28.0...
# 2  2014-1-3...          64.0...           46.0...          28.0...
# 3  2014-1-4...          66.0...           47.0...          28.0...
# 4  2014-1-5...          61.0...           44.0...          26.0...
#
#   Max Dew PointF MeanDew PointF Min DewpointF Max Humidity  Mean Humidity  \
# 0        14.0...         9.0...        5.0...      48.0...        32.0...
# 1        22.0...        19.0...       16.0...      58.0...        36.0...
# 2        24.0...        21.0...       15.0...      61.0...        40.0...
# 3        25.0...        21.0...       16.0...      61.0...        42.0...
# 4        18.0...         7.0...       -1.0...      56.0...        30.0...
#
#    Min Humidity   ...     Mean VisibilityMiles  Min VisibilityMiles  \
# 0       15.0...   ...                   nan...               nan...
# 1       19.0...   ...                  10.0...              10.0...
# 2       22.0...   ...                   nan...               nan...
# 3       20.0...   ...                   nan...               nan...
# 4        9.0...   ...                   nan...               nan...
#
#    Max Wind SpeedMPH  Mean Wind SpeedMPH  Max Gust SpeedMPH PrecipitationIn  \
# 0             7.0...              2.0...             nan...          0.0...
# 1             9.0...              2.0...             nan...          0.0...
# 2             9.0...              3.0...             nan...          0.0...
# 3             9.0...              4.0...             nan...          0.0...
# 4            10.0...              4.0...             nan...          0.0...
#
#    CloudCover  Events  WindDirDegrees is_cool?
# 0      0.0...  nan...          203...  cool...
# 1      0.0...  nan...          135...  cool...
# 2      0.0...  nan...          205...  cool...
# 3      0.0...  nan...          148...  cool...
# 4      0.0...  nan...          195...  cool...
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 删除数据

# %%
df = df.drop(['is_cool?'],axis=1) # 利用drop去掉最后一列
df.head()
# Out:
#         PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1              63.0               42.0              24.0
# 1  2014-1-2              66.0               47.0              28.0
# 2  2014-1-3              64.0               46.0              28.0
# 3  2014-1-4              66.0               47.0              28.0
# 4  2014-1-5              61.0               44.0              26.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            14.0             9.0            5.0          48.0
# 1            22.0            19.0           16.0          58.0
# 2            24.0            21.0           15.0          61.0
# 3            25.0            21.0           16.0          61.0
# 4            18.0             7.0           -1.0          56.0
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0            32.0           15.0       ...                          NaN
# 1            36.0           19.0       ...                         10.0
# 2            40.0           22.0       ...                          NaN
# 3            42.0           20.0       ...                          NaN
# 4            30.0            9.0       ...                          NaN
#
#     Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 0                    NaN                   NaN                 7.0
# 1                   10.0                  10.0                 9.0
# 2                    NaN                   NaN                 9.0
# 3                    NaN                   NaN                 9.0
# 4                    NaN                   NaN                10.0
#
#     Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 0                  2.0                 NaN              0.0          0.0
# 1                  2.0                 NaN              0.0          0.0
# 2                  3.0                 NaN              0.0          0.0
# 3                  4.0                 NaN              0.0          0.0
# 4                  4.0                 NaN              0.0          0.0
#
#     Events   WindDirDegrees
# 0      NaN              203
# 1      NaN              135
# 2      NaN              205
# 3      NaN              148
# 4      NaN              195
#
# [5 rows x 23 columns]

# %%
# 还好不是彻底改变
df.head()
# Out:
#         PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1              63.0               42.0              24.0
# 1  2014-1-2              66.0               47.0              28.0
# 2  2014-1-3              64.0               46.0              28.0
# 3  2014-1-4              66.0               47.0              28.0
# 4  2014-1-5              61.0               44.0              26.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            14.0             9.0            5.0          48.0
# 1            22.0            19.0           16.0          58.0
# 2            24.0            21.0           15.0          61.0
# 3            25.0            21.0           16.0          61.0
# 4            18.0             7.0           -1.0          56.0
#
#     Mean Humidity   Min Humidity    ...      Mean VisibilityMiles  \
# 0            32.0           15.0    ...                       NaN
# 1            36.0           19.0    ...                      10.0
# 2            40.0           22.0    ...                       NaN
# 3            42.0           20.0    ...                       NaN
# 4            30.0            9.0    ...                       NaN
#
#     Min VisibilityMiles   Max Wind SpeedMPH   Mean Wind SpeedMPH  \
# 0                   NaN                 7.0                  2.0
# 1                  10.0                 9.0                  2.0
# 2                   NaN                 9.0                  3.0
# 3                   NaN                 9.0                  4.0
# 4                   NaN                10.0                  4.0
#
#     Max Gust SpeedMPH  PrecipitationIn   CloudCover   Events   WindDirDegrees  \
# 0                 NaN              0.0          0.0      NaN              203
# 1                 NaN              0.0          0.0      NaN              135
# 2                 NaN              0.0          0.0      NaN              205
# 3                 NaN              0.0          0.0      NaN              148
# 4                 NaN              0.0          0.0      NaN              195
#
#    is_cool?
# 0      cool
# 1      cool
# 2      cool
# 3      cool
# 4      cool
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 修改索引

# %%
scores = {'英语':[90, 70,89],
         '数学':[64, 78, 45],
          '姓名':['w','l','s']
         }
d = pd.DataFrame(scores, index=['a','b','c'])
d
# Out:
#    英语  数学 姓名
# a  90  64  w
# b  70  78  l
# c  89  45  s

# %%
d.iloc[0]
# Out:
# 英语    90
# 数学    64
# 姓名     w
# Name: a, dtype: object

# %%
d.loc['a']
# Out:
# 英语    90
# 数学    64
# 姓名     w
# Name: a, dtype: object

# %%
df[:2]
# Out:
#         PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1              63.0               42.0              24.0
# 1  2014-1-2              66.0               47.0              28.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            14.0             9.0            5.0          48.0
# 1            22.0            19.0           16.0          58.0
#
#     Mean Humidity   Min Humidity    ...      Mean VisibilityMiles  \
# 0            32.0           15.0    ...                       NaN
# 1            36.0           19.0    ...                      10.0
#
#     Min VisibilityMiles   Max Wind SpeedMPH   Mean Wind SpeedMPH  \
# 0                   NaN                 7.0                  2.0
# 1                  10.0                 9.0                  2.0
#
#     Max Gust SpeedMPH  PrecipitationIn   CloudCover   Events   WindDirDegrees  \
# 0                 NaN              0.0          0.0      NaN              203
# 1                 NaN              0.0          0.0      NaN              135
#
#    is_cool?
# 0      cool
# 1      cool
#
# [2 rows x 24 columns]

# %% [markdown]
# ## 绘图

# %% [markdown]
# ### 线性图

# %%
# 在单元里显示
# %matplotlib inline
df.plot()

# %%
df['Max TemperatureF'].plot()

# %% [markdown]
# ### 柱状图

# %%
df[['Max TemperatureF','Mean TemperatureF']].plot.bar()

# %%
# 也可以这样写
df[['Max TemperatureF','Mean TemperatureF']].plot(kind='bar')

# %% [markdown]
# ### 直方图

# %%
# 单独
df[['Max TemperatureF','Mean TemperatureF']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000241EF388F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000241F0BE55C0>]],
#       dtype=object)

# %%
# 合并
df[['Max TemperatureF','Mean TemperatureF']].plot.hist()

# %% [markdown]
# ### 密度图

# %%
df[['Max TemperatureF','Mean TemperatureF']].plot.kde()

# %% [markdown]
# # reference

# %% [markdown]
# -   [The Pandas DataFrame: Make Working With Data Delightful](https://realpython.com/pandas-dataframe/)
